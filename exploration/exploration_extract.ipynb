# %% [markdown]
# # Tests de webscrapping du site de la FFR

# %% [markdown]
# Premier test récupération du score

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
from pprint import pprint

chrome_options = Options()
chrome_options.add_argument("--headless")


# Configuration de Selenium avec ChromeDriver
service = ChromeService(executable_path='/usr/bin/chromedriver')
driver = webdriver.Chrome(service=service, options=chrome_options)

# Remplacez par l'URL que vous souhaitez visiter
url_match = "https://competitions.ffr.fr/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/match-1428342.html"  # Remplacez cette URL par celle que vous voulez
driver.get(url_match)

# Attendez que le JavaScript se charge
time.sleep(5)  # Ajustez ce temps selon vos besoins

# Extraire le score
try:
    score = driver.find_element(By.CLASS_NAME, 'score')
    print("Score:", score.text.strip())
except Exception as e:
    print("Score non trouvé", e)
#Extraire 

driver.quit()
# Out:
# Score: 21-8

# %% [markdown]
# Tests récupération événements du match

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
from pprint import pprint

chrome_options = Options()
chrome_options.add_argument("--headless")


# Configuration de Selenium avec ChromeDriver
service = ChromeService(executable_path='/usr/bin/chromedriver')
driver = webdriver.Chrome(service=service, options=chrome_options)

# Remplacez par l'URL que vous souhaitez visiter
url_match = "https://competitions.ffr.fr/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/match-1428351.html"  # Remplacez cette URL par celle que vous voulez
driver.get(url_match)

# Attendez que le JavaScript se charge
time.sleep(5)  # Ajustez ce temps selon vos besoins

# Extraire le score
try:
    action_rows = driver.find_elements(By.CLASS_NAME, 'action-row')
except Exception as e:
    print("Actions non trouvé", e)

for row in action_rows:

    try:
        action = row.find_element(By.CLASS_NAME, 'action-name').text.strip()
        joueur = row.find_element(By.CLASS_NAME, 'player-name').text.strip()
        minutes = row.find_element(By.CLASS_NAME, 'minutes').text.strip()[:-1]

        if "Carton" in action:
            print(f"Action: {action}")
            print("Minutes:", minutes)
            print("--------------------------------------------")

        if action == "Remplacement tactique":
            splitted_text = joueur.split(".")
            initiale1 = splitted_text[0]
            initiale2 = splitted_text[1][-1]
            nom1 = splitted_text[1][:-1]
            nom2 = splitted_text[-1]

            first_player = f"{initiale1}.{nom1}"
            second_player = f"{initiale2}.{nom2}"

            print(f"Action:{first_player} remplace {second_player}")
            print("Minutes:", minutes)
            print("--------------------------------------------")

        if action == "Pénalité":
            points = 3

        if action == "Drop":
            points = 3

        if action == "Transformation":
            points = 2

        if action == "Essai":
            points = 5

    except Exception as e:
        print("Elément manquant dans la ligne d'actions")

driver.quit()
# Out:
# Action:L. Landart remplace I. Oyhamburu
# Minutes: 19
# --------------------------------------------
# Action:R. Mendivil remplace U. Benhamada
# Minutes: 26
# --------------------------------------------
# Action:E. Pierry remplace T. Bove
# Minutes: 26
# --------------------------------------------
# Action:P. Viart remplace A. Godon
# Minutes: 29
# --------------------------------------------
# Action: Carton blanc
# Minutes: 38
# --------------------------------------------
# Action:D. Astabie remplace B. Laurent
# Minutes: 41
# --------------------------------------------
# Action:J. Mourguiart remplace A. Morlas
# Minutes: 42
# --------------------------------------------
# Action:X. Saint Jean remplace L. Daguerre
# Minutes: 42
# --------------------------------------------
# Action:J. Bernatets remplace V. Pouyanne
# Minutes: 49
# --------------------------------------------
# Action: Carton blanc
# Minutes: 53
# --------------------------------------------

# %% [markdown]
# Test récupération url spécifique à chaque joueur

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
from pprint import pprint

chrome_options = Options()
chrome_options.add_argument("--headless")


# Configuration de Selenium avec ChromeDriver
service = ChromeService(executable_path='/usr/bin/chromedriver')
driver = webdriver.Chrome(service=service, options=chrome_options)

# Remplacez par l'URL que vous souhaitez visiter
url_match = "https://competitions.ffr.fr/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/match-1428351.html"  # Remplacez cette URL par celle que vous voulez
driver.get(url_match)

# Attendez que le JavaScript se charge
time.sleep(5)  # Ajustez ce temps selon vos besoins

# Extraire le score
try:
    score = driver.find_element(By.CLASS_NAME, 'score')
    print("Score:", score.text.strip())
except Exception as e:
    print("Score non trouvé", e)

# Extraire la composition
try:
    composition = {f"numero_{i}" : driver.find_element(By.ID, f'poste_{i}').get_attribute("href") for i in range(1,23)}
    pprint(composition)
except Exception as e:
     print("Joueur non trouvé", e)

#Extraire 

driver.quit()
# Out:
# Score: 21-8
# {'numero_1': 'https://competitions.ffr.fr/clubs/r-c-ustaritz-jatxou/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/joueurs/651287',
#  'numero_10': 'https://competitions.ffr.fr/clubs/r-c-ustaritz-jatxou/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/joueurs/522671',
#  'numero_11': 'https://competitions.ffr.fr/clubs/r-c-ustaritz-jatxou/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/joueurs/311359',
#  'numero_12': 'https://competitions.ffr.fr/clubs/r-c-ustaritz-jatxou/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/joueurs/1349603',
#  'numero_13': 'https://competitions.ffr.fr/clubs/r-c-ustaritz-jatxou/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/joueurs/1806806',
#  'numero_14': 'https://competitions.ffr.fr/clubs/r-c-ustaritz-jatxou/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/joueurs/1214543',
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
from pprint import pprint

chrome_options = Options()
chrome_options.add_argument("--headless")


# Configuration de Selenium avec ChromeDriver
service = ChromeService(executable_path='/usr/bin/chromedriver')
driver = webdriver.Chrome(service=service, options=chrome_options)

# Remplacez par l'URL que vous souhaitez visiter
url_match = "https://competitions.ffr.fr/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/match-1428351.html"  # Remplacez cette URL par celle que vous voulez
driver.get(url_match)

# Attendez que le JavaScript se charge
time.sleep(3)  # Ajustez ce temps selon vos besoins

tab_selector = driver.find_elements(By.CLASS_NAME, "tabSelector")
buttons = tab_selector[1].find_elements(By.TAG_NAME, "button")

equipe_1, equipe_2 = tab_selector[1].text.strip().split("\n")
print(f"Equipe 1 : {equipe_1}\nEquipe 2 : {equipe_2}")

#Extraire la composition
try:
    composition = {f"{equipe_1}" : {f"{i}" : driver.find_element(By.ID, f'poste_{i}').text.strip() for i in range(1,23)}}
    pprint(composition)
except Exception as e:
     print("Joueur non trouvé", e)

button = buttons[1]
driver.execute_script("arguments[0].scrollIntoView(true);", button)
button.click()

#Extraire la composition
try:
    composition = {f"{equipe_2}" : {f"{i}" : driver.find_element(By.ID, f'poste_{i}').text.strip() for i in range(1,23)}}
    pprint(composition)
except Exception as e:
     print("Joueur non trouvé", e)


# time.sleep(3)

driver.quit()
# Out:
# Equipe 1 : BIDART UNION CLUB
# Equipe 2 : R C USTARITZ JATXOU
# {'BIDART UNION CLUB': {'1': 'A. Jorge',
#                        '10': 'G. Amed',
#                        '11': 'D. Pasquet',
#                        '12': 'B. Daguerre',
#                        '13': 'Y. Dehez',
#                        '14': 'M. Zabalo',
#                        '15': 'I. Aramburu',
#                        '16': 'J. Matos De Sousa',
#                        '17': 'J. Bernatets',
#                        '18': 'T. Sorhouet',
#                        '19': 'R. Merlo',
#                        '2': 'A. Trompette',
#                        '20': 'U. Ravon',
#                        '21': 'D. Astabie',
#                        '22': 'P. Lissar',
#                        '3': 'V. Pouyanne',
#                        '4': 'J. Desrousseaux',
#                        '5': 'L. Lafargue',
#                        '6': 'P. Lafargue',
#                        '7': 'J. Mathieu',
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
from pprint import pprint

chrome_options = Options()
chrome_options.add_argument("--headless")


# Configuration de Selenium avec ChromeDriver
service = ChromeService(executable_path='/usr/bin/chromedriver')
driver = webdriver.Chrome(service=service, options=chrome_options)

# Remplacez par l'URL que vous souhaitez visiter
url_match = "https://competitions.ffr.fr/clubs/bidart-union-club/competitions/nouvelle-aquitaine-regionale-1-championnat-territorial/joueurs/1310849"
driver.get(url_match)

# Attendez que le JavaScript se charge
time.sleep(3)  # Ajustez ce temps selon vos besoins

player_name = driver.find_elements(By.CLASS_NAME, "name")
name = " ".join(i.text for i in player_name)
print(f"{name} a joué dans les clubs suivants aux périodes suivantes :")

clubs = driver.find_elements(By.CLASS_NAME, "player-clubs-line")

# On utilise seulement à partir du deuxième élément car le premier contient le club actuel mais est quand même contenu dans l'historique des clubs
for club in clubs[1:]:
    periode = club.find_element(By.CLASS_NAME,"player-clubs-date")
    club = club.find_element(By.CLASS_NAME,"player-clubs-name")
    print(f"{periode.text} : {club.text}")

driver.quit()
# Out:
# ALEXIS JORGE a joué dans les clubs suivants aux périodes suivantes :
# 2021-2025 : Bidart Union Club
# 2016-2020 : Anglet Olympique
# 2012-2016 : Biarritz Olympique Rugby
# 2007-2012 : Biarritz Olympique Rugby
# 2006-2007 : Saint Jean De Luz Ol
# 2004-2005 : Saint Jean De Luz Ol

# %%
import json

data = {
    "clé": "valeur",
    "exemple": [1, 2, 3]
}

chemin_dossier_parent = "../test_folder_2/test.json"

# Créer et écrire dans le fichier JSON
with open(chemin_dossier_parent, "w") as fichier:
    json.dump(data, fichier, indent=4)

print(f"Fichier JSON créé à : {chemin_dossier_parent}")
# Out:
# Fichier JSON créé à : ../test_folder_2/test.json
